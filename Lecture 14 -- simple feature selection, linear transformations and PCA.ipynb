# %%
from sklearn.feature_selection import VarianceThreshold
from sklearn.datasets import load_linnerud

# %%
linnerud_data = load_linnerud()
linnerud_data['feature_names']
# Out:
# ['Chins', 'Situps', 'Jumps']

# %%
D = linnerud_data['data']

# %%
D.shape
# Out:
# (20, 3)

# %%
D
# Out:
# array([[  5., 162.,  60.],
#        [  2., 110.,  60.],
#        [ 12., 101., 101.],
#        [ 12., 105.,  37.],
#        [ 13., 155.,  58.],
#        [  4., 101.,  42.],
#        [  8., 101.,  38.],
#        [  6., 125.,  40.],
#        [ 15., 200.,  40.],
#        [ 17., 251., 250.],
#        [ 17., 120.,  38.],
#        [ 13., 210., 115.],
#        [ 14., 215., 105.],
#        [  1.,  50.,  50.],
#        [  6.,  70.,  31.],
#        [ 12., 210., 120.],
#        [  4.,  60.,  25.],
#        [ 11., 230.,  80.],
#        [ 15., 225.,  73.],
#        [  2., 110.,  43.]])

# %%
import numpy as np
np.cov(D.T, ddof=1)
# Out:
# array([[  27.94473684,  230.10789474,  134.38421053],
#        [ 230.10789474, 3914.57631579, 2146.98421053],
#        [ 134.38421053, 2146.98421053, 2629.37894737]])

# %%
var_thresh = 100
sel = VarianceThreshold(threshold=var_thresh)
sel.fit_transform(D)
# Out:
# array([[162.,  60.],
#        [110.,  60.],
#        [101., 101.],
#        [105.,  37.],
#        [155.,  58.],
#        [101.,  42.],
#        [101.,  38.],
#        [125.,  40.],
#        [200.,  40.],
#        [251., 250.],
#        [120.,  38.],
#        [210., 115.],
#        [215., 105.],
#        [ 50.,  50.],
#        [ 70.,  31.],
#        [210., 120.],
#        [ 60.,  25.],
#        [230.,  80.],
#        [225.,  73.],
#        [110.,  43.]])

# %%
from sklearn.preprocessing import MinMaxScaler
normalized_D = MinMaxScaler().fit_transform(D)
normalized_D
# Out:
# array([[0.25      , 0.55721393, 0.15555556],
#        [0.0625    , 0.29850746, 0.15555556],
#        [0.6875    , 0.25373134, 0.33777778],
#        [0.6875    , 0.27363184, 0.05333333],
#        [0.75      , 0.52238806, 0.14666667],
#        [0.1875    , 0.25373134, 0.07555556],
#        [0.4375    , 0.25373134, 0.05777778],
#        [0.3125    , 0.37313433, 0.06666667],
#        [0.875     , 0.74626866, 0.06666667],
#        [1.        , 1.        , 1.        ],
#        [1.        , 0.34825871, 0.05777778],
#        [0.75      , 0.7960199 , 0.4       ],
#        [0.8125    , 0.82089552, 0.35555556],
#        [0.        , 0.        , 0.11111111],
#        [0.3125    , 0.09950249, 0.02666667],
#        [0.6875    , 0.7960199 , 0.42222222],
#        [0.1875    , 0.04975124, 0.        ],
#        [0.625     , 0.89552239, 0.24444444],
#        [0.875     , 0.87064677, 0.21333333],
#        [0.0625    , 0.29850746, 0.08      ]])

# %%
np.cov(normalized_D.T, ddof=1)
# Out:
# array([[0.10915913, 0.07155096, 0.03732895],
#        [0.07155096, 0.09689306, 0.04747339],
#        [0.03732895, 0.04747339, 0.05193835]])

# %%
var_thresh = 0.06
sel = VarianceThreshold(threshold=var_thresh)
sel.fit_transform(normalized_D)
# Out:
# array([[0.25      , 0.55721393],
#        [0.0625    , 0.29850746],
#        [0.6875    , 0.25373134],
#        [0.6875    , 0.27363184],
#        [0.75      , 0.52238806],
#        [0.1875    , 0.25373134],
#        [0.4375    , 0.25373134],
#        [0.3125    , 0.37313433],
#        [0.875     , 0.74626866],
#        [1.        , 1.        ],
#        [1.        , 0.34825871],
#        [0.75      , 0.7960199 ],
#        [0.8125    , 0.82089552],
#        [0.        , 0.        ],
#        [0.3125    , 0.09950249],
#        [0.6875    , 0.7960199 ],
#        [0.1875    , 0.04975124],
#        [0.625     , 0.89552239],
#        [0.875     , 0.87064677],
#        [0.0625    , 0.29850746]])

# %%
from sklearn.datasets import load_iris
D_iris = load_iris()['data']

# %%
load_iris().feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# ![image.png](attachment:ecec764e-9951-49bd-bc26-35e3c1823099.png)

# %%
D_iris.shape
# Out:
# (150, 4)

# %%
np.cov(D_iris.T)
# Out:
# array([[ 0.68569351, -0.042434  ,  1.27431544,  0.51627069],
#        [-0.042434  ,  0.18997942, -0.32965638, -0.12163937],
#        [ 1.27431544, -0.32965638,  3.11627785,  1.2956094 ],
#        [ 0.51627069, -0.12163937,  1.2956094 ,  0.58100626]])

# %%
np.cov(MinMaxScaler().fit_transform(D_iris).T)
# Out:
# array([[ 0.05290845, -0.00491134,  0.05999602,  0.05975355],
#        [-0.00491134,  0.03298254, -0.02328082, -0.02111795],
#        [ 0.05999602, -0.02328082,  0.08952249,  0.09149784],
#        [ 0.05975355, -0.02111795,  0.09149784,  0.10086914]])

# %%
D = D_iris[:, 1:3]

# %%
import matplotlib.pyplot as plt
plt.scatter(D[:,0], D[:, 1])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Scatter plot of data matrix D')
# Out:
# Text(0.5, 1.0, 'Scatter plot of data matrix D')

# %%
D.shape
# Out:
# (150, 2)

# %%
multivariate_mean = np.mean(D, axis=0)

# %%
print(multivariate_mean)
# Out:
# [3.05733333 3.758     ]

# %%
centered_data = D - multivariate_mean

# %%
print(centered_data)
# Out:
# [[ 0.44266667 -2.358     ]
#  [-0.05733333 -2.358     ]
#  [ 0.14266667 -2.458     ]
#  [ 0.04266667 -2.258     ]
#  [ 0.54266667 -2.358     ]
#  [ 0.84266667 -2.058     ]
#  [ 0.34266667 -2.358     ]
#  [ 0.34266667 -2.258     ]
#  [-0.15733333 -2.358     ]
#  [ 0.04266667 -2.258     ]
#  [ 0.64266667 -2.258     ]
#  [ 0.34266667 -2.158     ]
#  [-0.05733333 -2.358     ]
#  [-0.05733333 -2.658     ]
#  [ 0.94266667 -2.558     ]
#  [ 1.34266667 -2.258     ]
#  [ 0.84266667 -2.458     ]
#  [ 0.44266667 -2.358     ]
#  [ 0.74266667 -2.058     ]
#  [ 0.74266667 -2.258     ]
#  [ 0.34266667 -2.058     ]
#  [ 0.64266667 -2.258     ]
#  [ 0.54266667 -2.758     ]
#  [ 0.24266667 -2.058     ]
#  [ 0.34266667 -1.858     ]
#  [-0.05733333 -2.158     ]
#  [ 0.34266667 -2.158     ]
#  [ 0.44266667 -2.258     ]
#  [ 0.34266667 -2.358     ]
#  [ 0.14266667 -2.158     ]
#  [ 0.04266667 -2.158     ]
#  [ 0.34266667 -2.258     ]
#  [ 1.04266667 -2.258     ]
#  [ 1.14266667 -2.358     ]
#  [ 0.04266667 -2.258     ]
#  [ 0.14266667 -2.558     ]
#  [ 0.44266667 -2.458     ]
#  [ 0.54266667 -2.358     ]
#  [-0.05733333 -2.458     ]
#  [ 0.34266667 -2.258     ]
#  [ 0.44266667 -2.458     ]
#  [-0.75733333 -2.458     ]
#  [ 0.14266667 -2.458     ]
#  [ 0.44266667 -2.158     ]
#  [ 0.74266667 -1.858     ]
#  [-0.05733333 -2.358     ]
#  [ 0.74266667 -2.158     ]
#  [ 0.14266667 -2.358     ]
#  [ 0.64266667 -2.258     ]
#  [ 0.24266667 -2.358     ]
#  [ 0.14266667  0.942     ]
#  [ 0.14266667  0.742     ]
#  [ 0.04266667  1.142     ]
#  [-0.75733333  0.242     ]
#  [-0.25733333  0.842     ]
#  [-0.25733333  0.742     ]
#  [ 0.24266667  0.942     ]
#  [-0.65733333 -0.458     ]
#  [-0.15733333  0.842     ]
#  [-0.35733333  0.142     ]
#  [-1.05733333 -0.258     ]
#  [-0.05733333  0.442     ]
#  [-0.85733333  0.242     ]
#  [-0.15733333  0.942     ]
#  [-0.15733333 -0.158     ]
#  [ 0.04266667  0.642     ]
#  [-0.05733333  0.742     ]
#  [-0.35733333  0.342     ]
#  [-0.85733333  0.742     ]
#  [-0.55733333  0.142     ]
#  [ 0.14266667  1.042     ]
#  [-0.25733333  0.242     ]
#  [-0.55733333  1.142     ]
#  [-0.25733333  0.942     ]
#  [-0.15733333  0.542     ]
#  [-0.05733333  0.642     ]
#  [-0.25733333  1.042     ]
#  [-0.05733333  1.242     ]
#  [-0.15733333  0.742     ]
#  [-0.45733333 -0.258     ]
#  [-0.65733333  0.042     ]
#  [-0.65733333 -0.058     ]
#  [-0.35733333  0.142     ]
#  [-0.35733333  1.342     ]
#  [-0.05733333  0.742     ]
#  [ 0.34266667  0.742     ]
#  [ 0.04266667  0.942     ]
#  [-0.75733333  0.642     ]
#  [-0.05733333  0.342     ]
#  [-0.55733333  0.242     ]
#  [-0.45733333  0.642     ]
#  [-0.05733333  0.842     ]
#  [-0.45733333  0.242     ]
#  [-0.75733333 -0.458     ]
#  [-0.35733333  0.442     ]
#  [-0.05733333  0.442     ]
#  [-0.15733333  0.442     ]
#  [-0.15733333  0.542     ]
#  [-0.55733333 -0.758     ]
#  [-0.25733333  0.342     ]
#  [ 0.24266667  2.242     ]
#  [-0.35733333  1.342     ]
#  [-0.05733333  2.142     ]
#  [-0.15733333  1.842     ]
#  [-0.05733333  2.042     ]
#  [-0.05733333  2.842     ]
#  [-0.55733333  0.742     ]
#  [-0.15733333  2.542     ]
#  [-0.55733333  2.042     ]
#  [ 0.54266667  2.342     ]
#  [ 0.14266667  1.342     ]
#  [-0.35733333  1.542     ]
#  [-0.05733333  1.742     ]
#  [-0.55733333  1.242     ]
#  [-0.25733333  1.342     ]
#  [ 0.14266667  1.542     ]
#  [-0.05733333  1.742     ]
#  [ 0.74266667  2.942     ]
#  [-0.45733333  3.142     ]
#  [-0.85733333  1.242     ]
#  [ 0.14266667  1.942     ]
#  [-0.25733333  1.142     ]
#  [-0.25733333  2.942     ]
#  [-0.35733333  1.142     ]
#  [ 0.24266667  1.942     ]
#  [ 0.14266667  2.242     ]
#  [-0.25733333  1.042     ]
#  [-0.05733333  1.142     ]
#  [-0.25733333  1.842     ]
#  [-0.05733333  2.042     ]
#  [-0.25733333  2.342     ]
#  [ 0.74266667  2.642     ]
#  [-0.25733333  1.842     ]
#  [-0.25733333  1.342     ]
#  [-0.45733333  1.842     ]
#  [-0.05733333  2.342     ]
#  [ 0.34266667  1.842     ]
#  [ 0.04266667  1.742     ]
#  [-0.05733333  1.042     ]
#  [ 0.04266667  1.642     ]
#  [ 0.04266667  1.842     ]
#  [ 0.04266667  1.342     ]
#  [-0.35733333  1.342     ]
#  [ 0.14266667  2.142     ]
#  [ 0.24266667  1.942     ]
#  [-0.05733333  1.442     ]
#  [-0.55733333  1.242     ]
#  [-0.05733333  1.442     ]
#  [ 0.34266667  1.642     ]
#  [-0.05733333  1.342     ]]

# %%
np.mean(centered_data, axis=0)
# Out:
# array([-7.60872846e-16, -2.55203266e-15])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(D[:,0], D[:,1], s=10, c='b', marker='s', label='original data')
ax.scatter(centered_data[:,0], centered_data[:,1], s=10, c='r', marker='x', label='centered data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(loc='upper left')
plt.title('Scatter plot of centered and original data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of centered and original data')

# %%
np.mean(centered_data, axis = 0)
# Out:
# array([-7.60872846e-16, -2.55203266e-15])

# %%
A = np.array([[2,1],[1,-1]])
print(A)
# Out:
# [[ 2  1]
#  [ 1 -1]]

# %%
D[0,:]
# Out:
# array([3.5, 1.4])

# %%
A.dot(D[0,:])
# Out:
# array([8.4, 2.1])

# %%
A.dot(D[1,:])
# Out:
# array([7.4, 1.6])

# %%
D[1,:]
# Out:
# array([3. , 1.4])

# %%
D.T.shape
# Out:
# (2, 150)

# %%
linearly_transformed_data = A.dot(D.T)
print(linearly_transformed_data)
# Out:
# [[ 8.4  7.4  7.7  7.7  8.6  9.5  8.2  8.3  7.2  7.7  8.9  8.4  7.4  7.1
#    9.2 10.3  9.1  8.4  9.3  9.1  8.5  8.9  8.2  8.3  8.7  7.6  8.4  8.5
#    8.2  8.   7.8  8.3  9.7  9.8  7.7  7.6  8.3  8.6  7.3  8.3  8.3  5.9
#    7.7  8.6  9.5  7.4  9.2  7.8  8.9  8.  11.1 10.9 11.1  8.6 10.2 10.1
#   11.3  8.1 10.4  9.3  7.5 10.2  8.4 10.5  9.4 10.6 10.5  9.5  8.9  8.9
#   11.2  9.6  9.9 10.3 10.1 10.4 10.4 11.  10.3  8.7  8.6  8.5  9.3 10.5
#   10.5 11.3 10.9  9.  10.1  9.   9.6 10.6  9.2  7.9  9.6 10.2 10.  10.1
#    8.   9.7 12.6 10.5 11.9 11.4 11.8 12.6  9.5 12.1 10.8 13.3 11.5 10.7
#   11.5 10.  10.7 11.7 11.5 14.3 12.1  9.4 12.1 10.5 12.3 10.3 12.3 12.4
#   10.4 10.9 11.2 11.8 11.7 14.  11.2 10.7 10.8 12.1 12.4 11.7 10.8 11.6
#   11.8 11.3 10.5 12.3 12.3 11.2 10.  11.2 12.2 11.1]
#  [ 2.1  1.6  1.9  1.6  2.2  2.2  2.   1.9  1.5  1.6  2.2  1.8  1.6  1.9
#    2.8  2.9  2.6  2.1  2.1  2.3  1.7  2.2  2.6  1.6  1.5  1.4  1.8  2.
#    2.   1.6  1.5  1.9  2.6  2.8  1.6  2.   2.2  2.2  1.7  1.9  2.2  1.
#    1.9  1.9  1.9  1.6  2.2  1.8  2.2  1.9 -1.5 -1.3 -1.8 -1.7 -1.8 -1.7
#   -1.4 -0.9 -1.7 -1.2 -1.5 -1.2 -1.8 -1.8 -0.7 -1.3 -1.5 -1.4 -2.3 -1.4
#   -1.6 -1.2 -2.4 -1.9 -1.4 -1.4 -2.  -2.  -1.6 -0.9 -1.4 -1.3 -1.2 -2.4
#   -1.5 -1.1 -1.6 -2.1 -1.1 -1.5 -1.8 -1.6 -1.4 -1.  -1.5 -1.2 -1.3 -1.4
#   -0.5 -1.3 -2.7 -2.4 -2.9 -2.7 -2.8 -3.6 -2.  -3.4 -3.3 -2.5 -1.9 -2.6
#   -2.5 -2.5 -2.3 -2.1 -2.5 -2.9 -4.3 -2.8 -2.5 -2.1 -3.9 -2.2 -2.4 -2.8
#   -2.  -1.9 -2.8 -2.8 -3.3 -2.6 -2.8 -2.3 -3.  -3.1 -2.2 -2.4 -1.8 -2.3
#   -2.5 -2.  -2.4 -2.7 -2.4 -2.2 -2.5 -2.2 -2.  -2.1]]

# %%
linearly_transformed_data.shape
# Out:
# (2, 150)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(linearly_transformed_data[0,:], linearly_transformed_data[1,:], s=10, c='r', marker='x', label='linearly transformed data')
ax.scatter(D[:,0], D[:,1], s=10, c='b', marker='s', label='original data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(loc='lower right')
plt.title('Scatter plot of original data and linearly transformed data')
# Out:
# Text(0.5, 1.0, 'Scatter plot of original data and linearly transformed data')

# %%
Sigma = np.cov(D.T, ddof=1)

# %%
Sigma
# Out:
# array([[ 0.18997942, -0.32965638],
#        [-0.32965638,  3.11627785]])

# %%
n = D.shape[0]
1/(n-1)*np.dot(centered_data.T, centered_data)
# Out:
# array([[ 0.18997942, -0.32965638],
#        [-0.32965638,  3.11627785]])

# %%
import numpy.linalg as LA
evalues, evectors = LA.eig(Sigma)

# %%
print(evectors)
# Out:
# [[-0.99386764  0.11057628]
#  [-0.11057628 -0.99386764]]

# %%
print(evalues)
# Out:
# [0.15330233 3.15295494]

# %%
np.diag(Sigma)
# Out:
# array([0.18997942, 3.11627785])

# %%
total_var = sum(np.diag(Sigma))

# %%
total_var
# Out:
# 3.3062572706935125

# %%
sum(evalues)
# Out:
# 3.3062572706935125

# %%
evalues[1]/(evalues[0]+evalues[1])
# Out:
# 0.9536326686835204

# %%
coordinates_of_data_along_evec1 = evectors[:,1].T.dot(centered_data.T)

# %%
print(coordinates_of_data_along_evec1)
# Out:
# [ 2.39248833  2.33720019  2.45870221  2.24887105  2.40354596  2.13855855
#   2.3814307   2.28204394  2.32614256  2.24887105  2.31521682  2.18265717
#   2.33720019  2.63536048  2.64655     2.39262021  2.5361056   2.39248833
#   2.12750092  2.32627445  2.08327041  2.31521682  2.80109301  2.07221278
#   1.88449688  2.13842666  2.18265717  2.29310156  2.3814307   2.16054192
#   2.14948429  2.28204394  2.35944733  2.46989172  2.24887105  2.55808897
#   2.49187509  2.40354596  2.43658695  2.28204394  2.49187509  2.35918356
#   2.45870221  2.1937148   1.92872739  2.33720019  2.22688768  2.35931545
#   2.31521682  2.37037307 -0.92044777 -0.72167424 -1.13027892 -0.32425907
#  -0.86529152 -0.76590475 -0.90939014  0.38250591 -0.85423389 -0.18064179
#   0.13950187 -0.4456292  -0.3353167  -0.95362065  0.13963375 -0.6333451
#  -0.7437895  -0.37941532 -0.83225052 -0.20275705 -1.01983453 -0.26897093
#  -1.19662469 -0.96467828 -0.5560736  -0.64440273 -1.06406504 -1.24072332
#  -0.75484712  0.20584763 -0.11442791 -0.01504115 -0.18064179 -1.37328296
#  -0.7437895  -0.69955898 -0.9315054  -0.72180613 -0.34624244 -0.30214381
#  -0.68863324 -0.84317626 -0.29108619  0.37144828 -0.47880209 -0.4456292
#  -0.45668683 -0.5560736   0.69172383 -0.3683577  -2.20141807 -1.37328296
#  -2.13520419 -1.84810153 -2.03581743 -2.83091154 -0.79907763 -2.54380888
#  -2.09110557 -2.26763195 -1.31799482 -1.57205649 -1.73765714 -1.29601145
#  -1.36222534 -1.51676835 -1.73765714 -2.84183728 -3.17330234 -1.32918434
#  -1.91431541 -1.16345181 -2.95241356 -1.17450944 -1.90325778 -2.2124757
#  -1.06406504 -1.14133655 -1.85915916 -2.03581743 -2.35609298 -2.54367699
#  -1.85915916 -1.36222534 -1.88127441 -2.33397772 -1.79281339 -1.72659951
#  -1.04194979 -1.62721274 -1.82598627 -1.32905245 -1.37328296 -2.11308894
#  -1.90325778 -1.43949684 -1.29601145 -1.43949684 -1.59403986 -1.34011008]

# %%
evectors
# Out:
# array([[-0.99386764,  0.11057628],
#        [-0.11057628, -0.99386764]])

# %%
evectors[:,1]
# Out:
# array([ 0.11057628, -0.99386764])

# %%
coordinates_of_data_along_evec1[0]*evectors[:,1]
# Out:
# array([ 0.26455245, -2.37781673])

# %%
projected_data_on_evec1 = np.zeros((n,2))
for i in range(len(coordinates_of_data_along_evec1)):
    projected_data_on_evec1[i,:] = coordinates_of_data_along_evec1[i]*evectors[:,1]

pjdev1 = projected_data_on_evec1
# plot of centered data and its projection onto the first principial component (evec corresponding to largest eval)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(centered_data[:,0], centered_data[:,1], s=10, c='b', marker='s', label='centered data')
ax.scatter(pjdev1[:,0], pjdev1[:,1], s=10, c='r', marker='x', label='1-dimensional pca-transformed data')
plt.xlabel('X1')
plt.ylabel('X2')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.legend(loc='upper left')
plt.title('Scatter plot of centered and PCA-transformed data')
plt.savefig('centered_and_pca_transformed_data.png')

# %%
coordinates_of_data_along_evec2= evectors[:,0].T.dot(centered_data.T) 

projected_data_on_evec2 = np.zeros((n,2))
for i in range(len(coordinates_of_data_along_evec2)):
    projected_data_on_evec2[i,:] = coordinates_of_data_along_evec2[i]*evectors[:,0]

pjdev2 = projected_data_on_evec2
# plot of centered data and its projection onto (a) first PC and (b) second PC
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(centered_data[:,0], centered_data[:,1], s=10, c='b', marker='s', label='centered data')
ax.scatter(pjdev1[:,0], pjdev1[:,1], s=10, c='r', marker='^', label='1-dimensional pca-transformed data')
ax.scatter(pjdev2[:,0], pjdev2[:,1], s=10, c='g', marker='x', label='1-dimensional transformed data onto evec 2')
plt.xlabel('X1')
plt.ylabel('X2')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.legend(loc='upper left')
plt.title('Scatter plot of centered and linearly transformed data in direction of evec 2')
plt.savefig('centered_and_pca_transformed_data_evec2.png')

# %%
coordinates_of_data_in_evec_axes = evectors.T.dot(centered_data.T)
plt.scatter(coordinates_of_data_in_evec_axes[1,:], coordinates_of_data_in_evec_axes[0,:])
plt.xlabel('PC1 (evec corresponding to largest eval of Sigma) ')
plt.ylabel('PC2 (evec corresponding to second largest eval of Sigma) ')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('scatter plot of transformed data with eigenvectors as axes')
# Out:
# Text(0.5, 1.0, 'scatter plot of transformed data with eigenvectors as axes')

# %%
coordinates_of_data_in_evec_axes.shape
# Out:
# (2, 150)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_transformed_D = pca.fit_transform(D)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.95363267, 0.04636733])

# %%
evalues
# Out:
# array([0.15330233, 3.15295494])

# %%
evalues[1]/(evalues[0]+evalues[1])
# Out:
# 0.9536326686835204

# %%
evalues[0]/(evalues[0]+evalues[1])
# Out:
# 0.046367331316479625

# %%
pca.components_ #listed row-wise, in order of decreasing evalue magnitude
# Out:
# array([[-0.11057628,  0.99386764],
#        [ 0.99386764,  0.11057628]])

# %%
evectors
# Out:
# array([[-0.99386764,  0.11057628],
#        [-0.11057628, -0.99386764]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(coordinates_of_data_in_evec_axes[1,:], coordinates_of_data_in_evec_axes[0,:], s=10, c='b', marker='s', label='transformed data using pca')
ax.scatter(pca_transformed_D[:,0], pca_transformed_D[:,1], s=10, c='r', marker='x', label='transformed data using sklearn PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.legend(loc='lower right')
plt.title('Scatter plot of centered and sklearn PCA-transformed data using 2 principal components')
plt.savefig('centered_and_pca_transformed_data_2components.png')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(-1*coordinates_of_data_in_evec_axes[1,:], -1*coordinates_of_data_in_evec_axes[0,:], s=10, c='b', marker='s', label='transformed data using pca')
ax.scatter(pca_transformed_D[:,0], pca_transformed_D[:,1], s=10, c='r', marker='x', label='transformed data using sklearn PCA')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.legend(loc='lower right')
plt.title('Scatter plot of centered and sklearn PCA-transformed data using 2 principal components')
plt.savefig('centered_and_pca_transformed_data_2components.png')

# %%
np.cov(coordinates_of_data_in_evec_axes,ddof=1)
# Out:
# array([[1.53302326e-01, 4.76874319e-17],
#        [4.76874319e-17, 3.15295494e+00]])

# %%
np.cov(pca_transformed_D.T,ddof=1)
# Out:
# array([[3.15295494e+00, 4.76874319e-17],
#        [4.76874319e-17, 1.53302326e-01]])

# %%
D_iris = load_iris()['data']
pca = PCA(n_components=3)
pca_transformed_D_iris = pca.fit_transform(D_iris)
pca.explained_variance_ratio_
# Out:
# array([0.92461872, 0.05306648, 0.01710261])

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(pca_transformed_D_iris[:,0], pca_transformed_D_iris[:,1], pca_transformed_D_iris[:,2], c='r');
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
plt.title('PCA-transformed iris data using 3 principal components')
plt.savefig('pca-3d-transformed-iris-data.png')

# %%
D_iris.shape
# Out:
# (150, 4)

# %%
pca_transformed_D_iris
# Out:
# array([[-2.68412563,  0.31939725, -0.02791483],
#        [-2.71414169, -0.17700123, -0.21046427],
#        [-2.88899057, -0.14494943,  0.01790026],
#        [-2.74534286, -0.31829898,  0.03155937],
#        [-2.72871654,  0.32675451,  0.09007924],
#        [-2.28085963,  0.74133045,  0.16867766],
#        [-2.82053775, -0.08946138,  0.25789216],
#        [-2.62614497,  0.16338496, -0.02187932],
#        [-2.88638273, -0.57831175,  0.02075957],
#        [-2.6727558 , -0.11377425, -0.19763272],
#        [-2.50694709,  0.6450689 , -0.07531801],
#        [-2.61275523,  0.01472994,  0.10215026],
#        [-2.78610927, -0.235112  , -0.20684443],
#        [-3.22380374, -0.51139459,  0.06129967],
#        [-2.64475039,  1.17876464, -0.15162752],
#        [-2.38603903,  1.33806233,  0.2777769 ],
#        [-2.62352788,  0.81067951,  0.13818323],
#        [-2.64829671,  0.31184914,  0.02666832],
#        [-2.19982032,  0.87283904, -0.12030552],
#        [-2.5879864 ,  0.51356031,  0.21366517],
#        [-2.31025622,  0.39134594, -0.23944404],
#        [-2.54370523,  0.43299606,  0.20845723],
#        [-3.21593942,  0.13346807,  0.29239675],
#        [-2.30273318,  0.09870885,  0.03912326],
#        [-2.35575405, -0.03728186,  0.12502108],
#        [-2.50666891, -0.14601688, -0.25342004],
#        [-2.46882007,  0.13095149,  0.09491058],
#        [-2.56231991,  0.36771886, -0.07849421],
#        [-2.63953472,  0.31203998, -0.1459089 ],
#        [-2.63198939, -0.19696122,  0.04077108],
#        [-2.58739848, -0.20431849, -0.07722299],
#        [-2.4099325 ,  0.41092426, -0.14552497],
#        [-2.64886233,  0.81336382,  0.22566915],
#        [-2.59873675,  1.09314576,  0.15781081],
#        [-2.63692688, -0.12132235, -0.14304958],
#        [-2.86624165,  0.06936447, -0.16433231],
#        [-2.62523805,  0.59937002, -0.26835038],
#        [-2.80068412,  0.26864374,  0.09369908],
#        [-2.98050204, -0.48795834,  0.07292705],
#        [-2.59000631,  0.22904384, -0.0800823 ],
#        [-2.77010243,  0.26352753,  0.07724769],
#        [-2.84936871, -0.94096057, -0.34923038],
#        [-2.99740655, -0.34192606,  0.19250921],
#        [-2.40561449,  0.18887143,  0.26386795],
#        [-2.20948924,  0.43666314,  0.29874275],
#        [-2.71445143, -0.2502082 , -0.09767814],
#        [-2.53814826,  0.50377114,  0.16670564],
#        [-2.83946217, -0.22794557,  0.08372685],
#        [-2.54308575,  0.57941002, -0.01711502],
#        [-2.70335978,  0.10770608, -0.08929401],
#        [ 1.28482569,  0.68516047, -0.40656803],
#        [ 0.93248853,  0.31833364, -0.01801419],
#        [ 1.46430232,  0.50426282, -0.33832576],
#        [ 0.18331772, -0.82795901, -0.17959139],
#        [ 1.08810326,  0.07459068, -0.3077579 ],
#        [ 0.64166908, -0.41824687,  0.04107609],
#        [ 1.09506066,  0.28346827,  0.16981024],
#        [-0.74912267, -1.00489096,  0.01230292],
#        [ 1.04413183,  0.2283619 , -0.41533608],
#        [-0.0087454 , -0.72308191,  0.28114143],
#        [-0.50784088, -1.26597119, -0.26981718],
#        [ 0.51169856, -0.10398124,  0.13054775],
#        [ 0.26497651, -0.55003646, -0.69414683],
#        [ 0.98493451, -0.12481785, -0.06211441],
#        [-0.17392537, -0.25485421,  0.09045769],
#        [ 0.92786078,  0.46717949, -0.31462098],
#        [ 0.66028376, -0.35296967,  0.32802753],
#        [ 0.23610499, -0.33361077, -0.27116184],
#        [ 0.94473373, -0.54314555, -0.49951905],
#        [ 0.04522698, -0.58383438, -0.2350021 ],
#        [ 1.11628318, -0.08461685,  0.45962099],
#        [ 0.35788842, -0.06892503, -0.22985389],
#        [ 1.29818388, -0.32778731, -0.34785435],
#        [ 0.92172892, -0.18273779, -0.23107178],
#        [ 0.71485333,  0.14905594, -0.32180094],
#        [ 0.90017437,  0.32850447, -0.31620907],
#        [ 1.33202444,  0.24444088, -0.52170278],
#        [ 1.55780216,  0.26749545, -0.16492098],
#        [ 0.81329065, -0.1633503 ,  0.0354245 ],
#        [-0.30558378, -0.36826219, -0.31849158],
#        [-0.06812649, -0.70517213, -0.24421381],
#        [-0.18962247, -0.68028676, -0.30642056],
#        [ 0.13642871, -0.31403244, -0.17724277],
#        [ 1.38002644, -0.42095429,  0.01616713],
#        [ 0.58800644, -0.48428742,  0.4444335 ],
#        [ 0.80685831,  0.19418231,  0.38896306],
#        [ 1.22069088,  0.40761959, -0.23716701],
#        [ 0.81509524, -0.37203706, -0.61472084],
#        [ 0.24595768, -0.2685244 ,  0.18836681],
#        [ 0.16641322, -0.68192672, -0.06000923],
#        [ 0.46480029, -0.67071154, -0.02430686],
#        [ 0.8908152 , -0.03446444, -0.00994693],
#        [ 0.23054802, -0.40438585, -0.22941024],
#        [-0.70453176, -1.01224823, -0.10569115],
#        [ 0.35698149, -0.50491009,  0.01661717],
#        [ 0.33193448, -0.21265468,  0.08320429],
#        [ 0.37621565, -0.29321893,  0.07799635],
#        [ 0.64257601,  0.01773819, -0.20539497],
#        [-0.90646986, -0.75609337, -0.01259965],
#        [ 0.29900084, -0.34889781,  0.01058166],
#        [ 2.53119273, -0.00984911,  0.76016543],
#        [ 1.41523588, -0.57491635,  0.29632253],
#        [ 2.61667602,  0.34390315, -0.11078788],
#        [ 1.97153105, -0.1797279 ,  0.10842466],
#        [ 2.35000592, -0.04026095,  0.28538956],
#        [ 3.39703874,  0.55083667, -0.34843756],
#        [ 0.52123224, -1.19275873,  0.5456593 ],
#        [ 2.93258707,  0.3555    , -0.42023994],
#        [ 2.32122882, -0.2438315 , -0.34830439],
#        [ 2.91675097,  0.78279195,  0.42333542],
#        [ 1.66177415,  0.24222841,  0.24244019],
#        [ 1.80340195, -0.21563762, -0.03764817],
#        [ 2.1655918 ,  0.21627559,  0.03332664],
#        [ 1.34616358, -0.77681835,  0.28190288],
#        [ 1.58592822, -0.53964071,  0.62902933],
#        [ 1.90445637,  0.11925069,  0.47963982],
#        [ 1.94968906,  0.04194326,  0.04418617],
#        [ 3.48705536,  1.17573933,  0.13389487],
#        [ 3.79564542,  0.25732297, -0.51376776],
#        [ 1.30079171, -0.76114964, -0.34499504],
#        [ 2.42781791,  0.37819601,  0.21911932],
#        [ 1.19900111, -0.60609153,  0.51185551],
#        [ 3.49992004,  0.4606741 , -0.57318224],
#        [ 1.38876613, -0.20439933, -0.06452276],
#        [ 2.2754305 ,  0.33499061,  0.28615009],
#        [ 2.61409047,  0.56090136, -0.20553452],
#        [ 1.25850816, -0.17970479,  0.0458477 ],
#        [ 1.29113206, -0.11666865,  0.23125646],
#        [ 2.12360872, -0.20972948,  0.15418002],
#        [ 2.38800302,  0.4646398 , -0.44953019],
#        [ 2.84167278,  0.37526917, -0.49889808],
#        [ 3.23067366,  1.37416509, -0.11454821],
#        [ 2.15943764, -0.21727758,  0.20876317],
#        [ 1.44416124, -0.14341341, -0.15323389],
#        [ 1.78129481, -0.49990168, -0.17287519],
#        [ 3.07649993,  0.68808568, -0.33559229],
#        [ 2.14424331,  0.1400642 ,  0.73487894],
#        [ 1.90509815,  0.04930053,  0.16218024],
#        [ 1.16932634, -0.16499026,  0.28183584],
#        [ 2.10761114,  0.37228787,  0.02729113],
#        [ 2.31415471,  0.18365128,  0.32269375],
#        [ 1.9222678 ,  0.40920347,  0.1135866 ],
#        [ 1.41523588, -0.57491635,  0.29632253],
#        [ 2.56301338,  0.2778626 ,  0.29256952],
#        [ 2.41874618,  0.3047982 ,  0.50448266],
#        [ 1.94410979,  0.1875323 ,  0.17782509],
#        [ 1.52716661, -0.37531698, -0.12189817],
#        [ 1.76434572,  0.07885885,  0.13048163],
#        [ 1.90094161,  0.11662796,  0.72325156],
#        [ 1.39018886, -0.28266094,  0.36290965]])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(D_iris[:,0], D_iris[:,1], D_iris[:,2], c='b');
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('X3')
plt.title('PCA-transformed iris data using 3 principal components')
plt.savefig('iris-data-3d.png')
